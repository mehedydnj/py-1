# %% [markdown]
# <a href="https://colab.research.google.com/github/mehedydnj/py-1/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/rashakil-ds/Public-Datasets/main/churn.csv'
df1=pd.read_csv(url)

# %%
df1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df1.shape
# Out:
# (7043, 21)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(df1['Churn'])
# Out:
# <Axes: xlabel='count', ylabel='Churn'>

# %%
df1['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
churned = df1[df1.Churn == 'Yes'].shape[0]
retained= df1[df1.Churn == 'No'].shape[0]

# %%
ch_per =((churned/(churned+ retained))*100)

# %%
ch_per
# Out:
# 26.536987079369588

# %%
re_per =((retained/(churned+ retained))*100)

# %%
re_per
# Out:
# 73.4630129206304

# %%
df1['TotalCharges']=pd.to_numeric(df1['TotalCharges'], errors='coerce')
df1['TotalCharges'].fillna(df1['TotalCharges'].median(), inplace=True)
# Out:
# /tmp/ipykernel_4128/2761856295.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['TotalCharges'].fillna(df1['TotalCharges'].median(), inplace=True)

# %%
df1.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df1.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2281.916928
# std         0.368612    24.559481       30.090047   2265.270398
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
sns.countplot(x='gender',hue='Churn', data=df1)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df1['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
sns.countplot(x='MultipleLines',hue='Churn', data=df1)
# Out:
# <Axes: xlabel='MultipleLines', ylabel='count'>

# %%
sns.countplot(x='InternetService',hue='Churn', data=df1)
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
dt =df1.drop('customerID',axis=1)

# %%
df1.shape
# Out:
# (7043, 21)

# %%
dt.shape
# Out:
# (7043, 20)

# %%
df1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for column in  dt.columns:
  if dt[column].dtype==np.number:
    continue
  dt[column]=LabelEncoder().fit_transform(dt[column])
# Out:
# /tmp/ipykernel_4128/3068460055.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if dt[column].dtype==np.number:
# /tmp/ipykernel_4128/3068460055.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if dt[column].dtype==np.number:
# /tmp/ipykernel_4128/3068460055.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if dt[column].dtype==np.number:
# /tmp/ipykernel_4128/3068460055.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if dt[column].dtype==np.number:
# ...

# %%
dt.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
dt.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
x=dt.drop('Churn',axis=1)
y=dt['Churn']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
feature_x =StandardScaler().fit_transform(x)

# %%
feature_x
# Out:
# array([[-1.00955867, -0.43991649,  1.03453023, ...,  0.39855772,
#         -1.16032292, -0.99424194],
#        [ 0.99053183, -0.43991649, -0.96662231, ...,  1.33486261,
#         -0.25962894, -0.17324413],
#        [ 0.99053183, -0.43991649, -0.96662231, ...,  1.33486261,
#         -0.36266036, -0.95967407],
#        ...,
#        [-1.00955867, -0.43991649,  1.03453023, ...,  0.39855772,
#         -1.1686319 , -0.85446945],
#        [ 0.99053183,  2.27315869,  1.03453023, ...,  1.33486261,
#          0.32033821, -0.87206242],
#        [ 0.99053183, -0.43991649, -0.96662231, ..., -1.47405205,
#          1.35896134,  2.01428802]])

# %%
x_train,x_test,y_train,y_test=train_test_split(feature_x,y,test_size=.25,random_state=42)

# %%
x_test
# Out:
# array([[-1.00955867, -0.43991649,  1.03453023, ...,  0.39855772,
#         -1.32816441, -0.99647141],
#        [ 0.99053183, -0.43991649, -0.96662231, ..., -1.47405205,
#         -1.31320824, -0.56750761],
#        [-1.00955867, -0.43991649,  1.03453023, ...,  1.33486261,
#         -1.50930029, -0.55194545],
#        ...,
#        [ 0.99053183, -0.43991649, -0.96662231, ..., -0.53774716,
#          0.20401242, -0.140089  ],
#        [-1.00955867, -0.43991649, -0.96662231, ...,  0.39855772,
#         -0.99912861, -0.97993799],
#        [-1.00955867,  2.27315869, -0.96662231, ..., -0.53774716,
#          0.30039665,  0.76019858]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score ,classification_report,confusion_matrix

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8103350369108461

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[1157,  125],
#        [ 209,  270]])

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87      1282
#            1       0.68      0.56      0.62       479
#
#     accuracy                           0.81      1761
#    macro avg       0.77      0.73      0.75      1761
# weighted avg       0.80      0.81      0.80      1761

# %% [markdown]
# <a href="https://colab.research.google.com/github/mehedydnj/py-1/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-95f4701e-845f-475c-8db6-3e90b2b220a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95f4701e-845f-475c-8db6-3e90b2b220a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.config', 'archive.zip', 'sample_data']

# %%
import zipfile
with zipfile.ZipFile('archive.zip','r') as zip_ref:
  zip_ref.extractall('USA_Housing')

# %%
import pandas as pd
df =pd.read_csv('USA_Housing/USA_Housing.csv')

# %%
df.tail(20)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4980      75664.024482             5.789203                   6.415312
# 4981      71663.871293             6.150745                   7.311907
# 4982      58800.908770             5.976507                   7.304051
# 4983      69655.183954             7.721100                   6.077795
# 4984      62623.359828             5.071624                   6.771015
# 4985      75117.042949             6.036275                   6.538111
# 4986      71060.406015             5.718839                   7.222730
# 4987      65729.222330             6.237787                   6.860475
# 4988      67637.840665             7.056673                   5.774409
# 4989      47965.406896             5.694638                   7.363327
# 4990      52723.876555             5.452237                   8.124571
# 4991      74102.191890             5.657841                   7.683993
# ...

# %%
df.values
# Out:
# array([[79545.45857431678, 5.682861321615587, 7.009188142792237, ...,
#         23086.800502686456, 1059033.5578701235,
#         '208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101'],
#        [79248.64245482568, 6.0028998082752425, 6.730821019094919, ...,
#         40173.07217364482, 1505890.91484695,
#         '188 Johnson Views Suite 079\nLake Kathleen, CA 48958'],
#        [61287.067178656784, 5.865889840310001, 8.512727430375099, ...,
#         36882.15939970458, 1058987.9878760849,
#         '9127 Elizabeth Stravenue\nDanieltown, WI 06482-3489'],
#        ...,
#        [63390.68688550463, 7.250590614779546, 4.805080980291155, ...,
#         33266.145489652175, 1030729.5831522896,
#         '4215 Tracy Garden Suite 076\nJoshualand, VA 01707-9165'],
#        [68001.33123508695, 5.534388416220344, 7.130143864349472, ...,
#         42625.62015585088, 1198656.8724076871,
#         'USS Wallace\nFPO AE 73316'],
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %%
df.Price
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
df[['Area Population']]
# Out:
#       Area Population
# 0        23086.800503
# 1        40173.072174
# 2        36882.159400
# 3        34310.242831
# 4        26354.109472
# ...               ...
# 4995     22837.361035
# 4996     25616.115489
# 4997     33266.145490
# 4998     42625.620156
# 4999     46501.283803
#
# [5000 rows x 1 columns]

# %%
df['Area Population'].sort_values()
# Out:
# 314       172.610686
# 1530     3285.450538
# 2756     3883.448164
# 2534     4114.489353
# 4491     5727.485885
#             ...
# 3991    68311.695822
# 353     69553.988327
# 228     69575.449464
# 1595    69592.040236
# 4803    69621.713378
# Name: Area Population, Length: 5000, dtype: float64

# %%
df.sort_values('Area Population', ascending=True)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 314       68929.158074             7.590878                   6.891969
# 1530      85175.200626             7.750852                   7.271163
# 2756      62173.580099             5.098959                   5.662268
# 2534      79442.505795             6.300600                   5.983205
# 4491      66513.884448             6.778404                   8.044497
# ...                ...                  ...                        ...
# 3991      50041.125224             5.981267                   8.699555
# 353       72445.033303             5.488197                   6.509449
# 228       66574.709994             5.550265                   6.844150
# 1595      64350.284571             6.761203                   7.128710
# 4803      61846.135900             5.057578                   7.681141
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df=df.drop('Address', axis=1)

# %%
df.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 39.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.3 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile= ProfileReport(df, title='Pandas Profiling', explorative=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-08-11 03:55:59.316884&quot; name=date&gt;&lt;title&gt;Pandas Profiling&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
